# %%
pip install opencv-python

# %%
pip install ultralytics

# %%
import cv2
cap = cv2.VideoCapture(0)
cap.set(3, 640)  
cap.set(4, 480)  

while True:
    ret, img= cap.read()
    cv2.imshow('Webcam', img)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read()           #cap nesnesinden bir kare okur. success değişkeni, okuma işleminin başarılı olup olmadığını belirtir.
    results = model(img, stream=True)   #Okunan kareyi YOLO modeline ( model nesnesine) geçirerek nesne algılama işlemini gerçekleştirir. 

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)   #Algılanan nesnenin etrafına pembe bir dikdörtgen çizer.

            # confidence
            #:" Güven skorunu hesaplar ve yazdırır. Güven skoru, nesne algılama modellerinde, bir nesnenin doğru bir şekilde algılandığına dair bir ölçüdür. Bu skor, genellikle 0 ile 1 arasında bir değerdir, 1'e yaklaştıkça modelin o nesneyi daha fazla güvenle algıladığı anlamına gelir.
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])   
            print("Class name -->", classNames[cls])    #Sınıf etiketini belirler ve yazdırır

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 cup, 151.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.35
# Class name --> cup
# Speed: 8.0ms preprocess, 151.0ms inference, 1008.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cups, 101.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.32
# Class name --> cup
# Confidence ---> 0.29
# Class name --> cup
# Speed: 3.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cups, 105.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.4
# Class name --> cup
# Confidence ---> 0.32
# Class name --> cup
# Speed: 3.0ms preprocess, 105.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cups, 102.5ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Confidence ---> 0.39
# Class name --> cup
# ...
